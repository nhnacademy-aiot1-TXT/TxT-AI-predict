# %%
import influxdb_client, os, time
from influxdb_client import InfluxDBClient, Point, WritePrecision
from influxdb_client.client.write_api import SYNCHRONOUS

token = "oGQk6mmoPowjAdZ01wJL02I2ITd-n8e8H_Xu6_ZOBcxsalK-t4hXcyioTDv0HEbSa7lH6WGoU5FtboEvXZXcQw=="

# %%
from datetime import datetime

from influxdb_client import WritePrecision, InfluxDBClient, Point
from influxdb_client.client.write_api import SYNCHRONOUS

url = 'http://133.186.251.19:8086'
token = 'auLmfVaJpvWUbnMxhbixfgq5JjFrleKTNxnFphRZ_tfVHoypyyXhBe3zHT07tqRTylE15VRmjuNFX9-u9uv6nA=='
org = 'TXT'
bucket = 'jjunho_test'

with InfluxDBClient(url=url, token=token, org=org) as client:
    p = Point("measurement1") \
        .tag("tagname1", "tagvalue1") \
        .field("field1", value) \
        .time(datetime.utcnow(), WritePrecision.MS)

    with client.write_api(write_options=SYNCHRONOUS) as write_api:
        write_api.write(bucket=bucket, org="TXT" ,record=point)
        time.sleep(1)

# %%
from influxdb_client import InfluxDBClient

# influxdb connect
url = 'http://133.186.251.19:8086'
token = 'auLmfVaJpvWUbnMxhbixfgq5JjFrleKTNxnFphRZ_tfVHoypyyXhBe3zHT07tqRTylE15VRmjuNFX9-u9uv6nA=='
org = 'TXT'
bucket = 'jjunho_test'

# data 저장할 배열 선언
data_array = []

# influxdb _jjunho_test bucket에서 data read
with InfluxDBClient(url=url, token=token, org=org) as client:
    query_api = client.query_api()

    tables = query_api.query('from(bucket: "jjunho_test") |> range(start: -1d)')

    for table in tables:
        for record in table.records:
            print(str(record["_time"]) + " - " + record.get_measurement()
                  + " " + record.get_field() + "=" + str(record.get_value()))
#             # data 배열에 추가
#             data_array.append({
#                 "time": str(record["_time"]),
#                 "measurement" : record.get_measurement(),
#                 "field": record.get_field(),
#                 "vlaue": str(record.get_value())
#             })

# # 배열에 저장된 데이터 출력
# for data in data_array:
#     print(data)
# Out:
# 2024-04-13 10:35:36.882849+00:00 - measurement1 field1=0
# 2024-04-13 08:20:45.180000+00:00 - split_data class=storage
# 2024-04-13 08:20:45.222000+00:00 - split_data class=storage
# 2024-04-13 08:20:49.414000+00:00 - split_data class=class_a
# 2024-04-13 08:21:00.162000+00:00 - split_data class=server_room
# 2024-04-13 08:21:00.423000+00:00 - split_data class=class_a
# 2024-04-13 08:21:11.890000+00:00 - split_data class=class_a
# 2024-04-13 08:21:14.938000+00:00 - split_data class=office
# 2024-04-13 08:21:38.810000+00:00 - split_data class=lobby
# 2024-04-13 08:21:40.089000+00:00 - split_data class=class_a
# 2024-04-13 08:21:45.188000+00:00 - split_data class=storage
# 2024-04-13 08:21:48.889000+00:00 - split_data class=class_b
# 2024-04-13 08:21:49.637000+00:00 - split_data class=class_a
# 2024-04-13 08:22:00.154000+00:00 - split_data class=server_room
# 2024-04-13 08:22:00.432000+00:00 - split_data class=class_a
# 2024-04-13 08:22:11.876000+00:00 - split_data class=class_a
# ...

# %%
from influxdb_client import InfluxDBClient
import pandas as pd

SELECT 
  value AS co2,
  place,
  device_name,
  devEui,
  class
FROM 
  your_measurement_name
WHERE 
  time = '2024-04-12T05:00:49.451Z'
